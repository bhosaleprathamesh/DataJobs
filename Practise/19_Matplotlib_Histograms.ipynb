# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_da_india = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'India')].copy()
df_da_india = df_da_india.dropna(subset=['salary_year_avg'])
df_da_india
# Out:
#        job_title_short                                          job_title  \
# 11412     Data Analyst                               Data Quality Analyst
# 27487     Data Analyst                                Data Architect 2023
# 29583     Data Analyst                     Senior Business & Data Analyst
# 32890     Data Analyst                           Data Analyst - Transport
# 41257     Data Analyst                                Junior Data Analyst
# ...                ...                                                ...
# 774606    Data Analyst                             Financial Data Analyst
# 774809    Data Analyst  IN RBIN Dy. Manager/ Asst Manager Data Analyst...
# 777313    Data Analyst                                       Data Analyst
# 784033    Data Analyst                           Recruitment Data Analyst
# 785515    Data Analyst                                       Data Analyst
#
#                        job_location          job_via job_schedule_type  \
# ...

# %%
df_da_india['salary_year_avg'].plot(kind='hist',
bins=15,
edgecolor='black',
)

plt.title('Distribution of Indias Data Analyst Yearly Salaries')
plt.xlabel('Yearly Salary')
plt.ylabel('Number of Jobs')
plt.show()

# %%
df_da_india['salary_year_avg'].plot(kind='hist',
bins=30,
edgecolor='black',
)

ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K'))

plt.title("Distribution of India's Data Analyst Yearly Salaries in $(USD)")
plt.xlabel('Yearly Salary')
plt.xlim(0, 250000)
plt.ylabel('Number of Jobs')
plt.show()

# %%
import seaborn as sns

# %%
sns.displot(df_da_india['salary_year_avg'], kind='kde', fill=True)
ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K'))

plt.title("Distribution of India's Data Analyst Yearly Salaries in $(USD)")
plt.xlabel('Yearly Salary')
plt.xlim(0, 250000)
plt.ylabel('Number of Jobs')
plt.show()

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
df_explode = df.explode('job_skills')
df_explode
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# ...                      ...
# 785739         Data Engineer
# 785739         Data Engineer
# 785739         Data Engineer
# 785740     Software Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# ...                                                   ...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# ...

# %%
df_explode['job_skills'].plot(kind='hist')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df_explode['job_skills'].plot(kind='hist')
#
# File c:\Users\bprat\anaconda3\envs\py_project\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\bprat\anaconda3\envs\py_project\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...
