# %%
#Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt 

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup 
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_altered = df.copy()

# %%
id(df)
# Out:
# 2025355192208

# %%
id(df_altered)
# Out:
# 2025355286544

# %%
df_altered.sample(n=8)
# Out:
#              job_title_short  \
# 241859          Data Analyst
# 379117        Data Scientist
# 594473         Data Engineer
# 180629         Data Engineer
# 729500         Data Engineer
# 209113  Senior Data Engineer
# 657695        Data Scientist
# 290215         Data Engineer
#
#                                                 job_title  \
# 241859  Master Data Specialist | Pricing Analyst |  Hy...
# 379117  Data Science - - Natural Language Processing S...
# 594473             AWS Data Engineer (Contract) - Gauteng
# 180629                               Data Engineer, Zeist
# 729500                                      Data Engineer
# 209113                               Senior Data Engineer
# 657695               Graduate Data Scientist (2024 Start)
# 290215                                      Data Engineer
#
#                          job_location              job_via job_schedule_type  \
# 241859                    Philippines         via LinkedIn              None
# 379117               Lahore, Pakistan         via LinkedIn         Full-time
# 594473          Midrand, South Africa           via Indeed        Contractor
# 180629             Zeist, Netherlands         via LinkedIn         Full-time
# 729500        Ridderkerk, Netherlands            via BeBee         Full-time
# 209113                 Kraków, Poland      via Trabajo.org         Full-time
# 657695                     London, UK           via Indeed         Full-time
# 290215  's-Hertogenbosch, Netherlands  via BeBee Nederland         Full-time
#
#         job_work_from_home search_location     job_posted_date  \
# 241859               False     Philippines 2023-04-12 07:45:49
# 379117               False        Pakistan 2023-11-22 18:20:09
# 594473               False    South Africa 2023-05-02 09:16:26
# 180629               False     Netherlands 2023-02-17 15:49:28
# 729500               False     Netherlands 2023-12-08 21:27:54
# 209113               False          Poland 2023-01-24 22:20:02
# 657695               False  United Kingdom 2023-08-29 10:38:24
# 290215               False     Netherlands 2023-01-14 17:23:42
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 241859                   True                 False     Philippines
# 379117                  False                 False        Pakistan
# 594473                  False                 False    South Africa
# 180629                   True                 False     Netherlands
# 729500                   True                 False     Netherlands
# 209113                  False                 False          Poland
# 657695                  False                 False  United Kingdom
# 290215                   True                 False     Netherlands
#
#        salary_rate  salary_year_avg  salary_hour_avg            company_name  \
# 241859        None              NaN              NaN     Genpact Philippines
# 379117        None              NaN              NaN             VentureDive
# 594473        None              NaN              NaN  Full Circle Resourcing
# 180629        None              NaN              NaN              Optimadata
# 729500        None              NaN              NaN          Experis iSense
# 209113        None              NaN              NaN                   Aptiv
# 657695        None              NaN              NaN                 Optiver
# 290215        None              NaN              NaN                   IQVIA
#
#                                                job_skills  \
# 241859                                   ['sap', 'excel']
# 379117  ['python', 'azure', 'aws', 'gcp', 'nltk', 'ten...
# 594473  ['python', 'sql', 'powershell', 'bash', 'dynam...
# 180629                  ['python', 'c#', 'azure', 'word']
# 729500  ['python', 'sql', 'powershell', 'nosql', 'neo4...
# 209113                       ['python', 'aws', 'express']
# 657695        ['go', 'python', 'pandas', 'numpy', 'word']
# 290215                       ['python', 'sql', 'airflow']
#
#                                           job_type_skills
# 241859                {'analyst_tools': ['sap', 'excel']}
# 379117  {'cloud': ['azure', 'aws', 'gcp'], 'libraries'...
# 594473  {'async': ['confluence', 'jira'], 'cloud': ['a...
# 180629  {'analyst_tools': ['word'], 'cloud': ['azure']...
# 729500  {'cloud': ['azure'], 'databases': ['neo4j'], '...
# 209113  {'cloud': ['aws'], 'programming': ['python'], ...
# 657695  {'analyst_tools': ['word'], 'libraries': ['pan...
# 290215  {'libraries': ['airflow'], 'programming': ['py...

# %%
df_altered.sample(frac=0.1, replace=False)
# Out:
#              job_title_short                                       job_title  \
# 690855          Data Analyst                           Business Data Analyst
# 697048  Senior Data Engineer                            Senior Data Engineer
# 82094          Data Engineer  UAE National Data Engineer Enterprise IT Dubai
# 270813     Software Engineer                           Sr. Platform Engineer
# 354105          Data Analyst                    Data Analytics IT Specialist
# ...                      ...                                             ...
# 331003          Data Analyst                    Clinical Statistical Analyst
# 409781          Data Analyst                       Supply Chain Data Analyst
# 769462         Data Engineer                          Data Engineer Big Data
# 123047          Data Analyst                     Retail Analytics Consultant
# 85601         Data Scientist                Front End Data Science Developer
#
#                         job_location              job_via job_schedule_type  \
# 690855             Mountain View, CA            via BeBee         Full-time
# 697048                    Irvine, CA         via LinkedIn         Full-time
# 82094   Dubai - United Arab Emirates            via BeBee         Full-time
# 270813                   Philippines            via BeBee              None
# 354105           Calgary, AB, Canada         via LinkedIn         Full-time
# ...                              ...                  ...               ...
# 331003                 Cork, Ireland      via Recruit.net         Full-time
# 409781                 Covington, GA            via BeBee         Full-time
# 769462           Arnhem, Netherlands            via BeBee         Full-time
# 123047                     Australia  via BeBee Australia         Full-time
# 85601                 Sacramento, CA            via BeBee         Full-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 690855               False  California, United States 2023-03-02 10:01:57
# 697048               False     Florida, United States 2023-01-13 03:14:14
# 82094                False       United Arab Emirates 2023-09-10 00:19:20
# 270813               False                Philippines 2023-08-26 07:14:08
# 354105               False                     Canada 2023-03-07 23:45:03
# ...                    ...                        ...                 ...
# 331003               False                    Ireland 2023-02-24 23:57:18
# 409781               False                    Georgia 2023-03-17 17:04:55
# 769462               False                Netherlands 2023-10-07 01:17:36
# 123047               False                  Australia 2023-09-23 08:32:04
# 85601                False  California, United States 2023-01-17 00:20:28
#
#         job_no_degree_mention  job_health_insurance           job_country  \
# 690855                   True                 False         United States
# 697048                  False                  True         United States
# 82094                   False                 False  United Arab Emirates
# 270813                   True                 False           Philippines
# 354105                  False                 False                Canada
# ...                       ...                   ...                   ...
# 331003                  False                 False               Ireland
# 409781                  False                  True         United States
# 769462                   True                 False           Netherlands
# 123047                   True                 False             Australia
# 85601                   False                 False         United States
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 690855        None              NaN              NaN
# 697048        None              NaN              NaN
# 82094         None              NaN              NaN
# 270813        None              NaN              NaN
# 354105        None              NaN              NaN
# ...            ...              ...              ...
# 331003        None              NaN              NaN
# 409781        None              NaN              NaN
# 769462        None              NaN              NaN
# 123047        None              NaN              NaN
# 85601         None              NaN              NaN
#
#                     company_name  \
# 690855                    ICONMA
# 697048        Motion Recruitment
# 82094                  AlFuttaim
# 270813        iSupport Worldwide
# 354105                  Enbridge
# ...                          ...
# 331003  Life Science Recruitment
# 409781                   Novolex
# 769462                 Alliander
# 123047           Spotlight Group
# 85601                       Meta
#
#                                                job_skills  \
# 690855                                               None
# 697048  ['python', 'snowflake', 'numpy', 'pandas', 'sc...
# 82094   ['python', 'sql', 'databricks', 'azure', 'pysp...
# 270813  ['java', 'kotlin', 'python', 'sql', 'sql serve...
# 354105  ['python', 'scala', 'javascript', 'databricks'...
# ...                                                   ...
# 331003                                               None
# 409781  ['sql', 'cognos', 'power bi', 'excel', 'powerp...
# 769462                           ['sql', 'python', 'aws']
# 123047                            ['power bi', 'tableau']
# 85601   ['php', 'javascript', 'html', 'css', 'react', ...
#
#                                           job_type_skills
# 690855                                               None
# 697048  {'cloud': ['snowflake'], 'libraries': ['numpy'...
# 82094   {'cloud': ['databricks', 'azure'], 'libraries'...
# 270813  {'cloud': ['azure', 'aws', 'gcp'], 'databases'...
# 354105  {'cloud': ['databricks'], 'libraries': ['kafka...
# ...                                                   ...
# 331003                                               None
# 409781  {'analyst_tools': ['cognos', 'power bi', 'exce...
# 769462  {'cloud': ['aws'], 'programming': ['sql', 'pyt...
# 123047         {'analyst_tools': ['power bi', 'tableau']}
# 85601   {'libraries': ['react', 'graphql'], 'programmi...
#
# [78574 rows x 17 columns]
