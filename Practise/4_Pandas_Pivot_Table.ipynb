# %%
#Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt 

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup 
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.pivot_table(index='job_title_short', aggfunc='size')
# Out:
# job_title_short
# Business Analyst              49063
# Cloud Engineer                12331
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Machine Learning Engineer     14080
# Senior Data Analyst           29216
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Software Engineer             44929
# dtype: int64

# %%
# similar to groupby we use jobtitleshort as index and salary yearavg as values to find there median 
df.pivot_table(values='salary_year_avg', index='job_title_short', aggfunc='median')
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %%
#to calculate median salary for these different job titles broken down by countries hence we use (columns) attribute
#groupby cant do this in one line of code hence we use pivot table
df.pivot_table(values='salary_year_avg',columns='job_country', index='job_title_short', aggfunc='median')
# Out:
# job_country                  Albania  Algeria  Argentina   Armenia  Australia  \
# job_title_short
# Business Analyst                 NaN      NaN   71100.00       NaN    70000.0
# Cloud Engineer                   NaN      NaN  197500.00       NaN   110000.0
# Data Analyst                49950.00  44100.0   92771.75  100500.0   109500.0
# Data Engineer                    NaN  45000.0   96773.00   48750.0   106712.5
# Data Scientist              69981.25      NaN   71000.00       NaN   139216.0
# Machine Learning Engineer        NaN      NaN  101029.00   87021.0   101029.0
# Senior Data Analyst              NaN      NaN        NaN       NaN    50640.0
# Senior Data Engineer             NaN      NaN  147500.00       NaN   147500.0
# Senior Data Scientist      157500.00      NaN        NaN       NaN   157500.0
# Software Engineer                NaN      NaN  174500.00       NaN   118350.0
#
# job_country                  Austria  Azerbaijan   Bahamas  Bangladesh  \
# job_title_short
# ...

# %%
#to get long table instead of wide table we just move around the values 
df.pivot_table(values='salary_year_avg',columns='job_title_short', index='job_country', aggfunc='median')
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# Albania                       NaN             NaN      49950.00
# Algeria                       NaN             NaN      44100.00
# Argentina                 71100.0        197500.0      92771.75
# Armenia                       NaN             NaN     100500.00
# Australia                 70000.0        110000.0     109500.00
# ...                           ...             ...           ...
# Uruguay                       NaN             NaN     100500.00
# Uzbekistan                    NaN             NaN           NaN
# Vietnam                   79200.0             NaN      75550.00
# Zambia                        NaN             NaN           NaN
# Zimbabwe                      NaN             NaN      63000.00
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# Albania                    NaN        69981.25                        NaN
# ...

# %%
top_countries = df['job_country'].value_counts()

top_countries
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
#                    ...
# Guinea                 4
# Mauritania             3
# Lesotho                3
# Bhutan                 3
# Maldives               2
# Name: count, Length: 160, dtype: int64

# %%
#to filter the countries we want we will make a seperate varaible containing those countries in an array
top_countries = df['job_country'].value_counts().head(6)
top_countries
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Name: count, dtype: int64

# %%
top_countries = df['job_country'].value_counts().head(6).index
top_countries
# Out:
# Index(['United States', 'India', 'United Kingdom', 'France', 'Germany',
#        'Spain'],
#       dtype='object', name='job_country')

# %%
df_job_country_salary = df.pivot_table(values='salary_year_avg',columns='job_title_short', index='job_country', aggfunc='median')
df_job_country_salary
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# Albania                       NaN             NaN      49950.00
# Algeria                       NaN             NaN      44100.00
# Argentina                 71100.0        197500.0      92771.75
# Armenia                       NaN             NaN     100500.00
# Australia                 70000.0        110000.0     109500.00
# ...                           ...             ...           ...
# Uruguay                       NaN             NaN     100500.00
# Uzbekistan                    NaN             NaN           NaN
# Vietnam                   79200.0             NaN      75550.00
# Zambia                        NaN             NaN           NaN
# Zimbabwe                      NaN             NaN      63000.00
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# Albania                    NaN        69981.25                        NaN
# ...

# %%
#after filtering the countries now we want to filter it from df_job_country_salary using loc 
df_job_country_salary = df_job_country_salary.loc[top_countries]
df_job_country_salary
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# United States             90000.0        116100.0       90000.0
# India                     64800.0             NaN      100500.0
# United Kingdom            56700.0             NaN       87750.0
# France                    89100.0        105968.0       69175.0
# Germany                   89100.0         89100.0      103750.0
# Spain                     86400.0         89100.0       91977.0
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# United States         125000.0        130000.0                   150000.0
# India                 147500.0        114008.0                    79200.0
# United Kingdom        110000.0        105300.0                   149653.0
# France                 98301.5         88128.0                    80850.0
# Germany               147500.0        131560.0                    89100.0
# ...

# %%
#now to filter the job titles 
job_titles = ['Data Analyst', 'Data Engineer', 'Data Scientist']

df_job_country_salary = df_job_country_salary[job_titles]
df_job_country_salary
# Out:
# job_title_short  Data Analyst  Data Engineer  Data Scientist
# job_country
# United States         90000.0       125000.0        130000.0
# India                100500.0       147500.0        114008.0
# United Kingdom        87750.0       110000.0        105300.0
# France                69175.0        98301.5         88128.0
# Germany              103750.0       147500.0        131560.0
# Spain                 91977.0       133000.0         88128.0

# %%
#plotting
df_job_country_salary.plot(kind='bar')
plt.ylabel('Median Salary($USD)')
plt.xlabel('')
plt.title('Median Salary By Country And Job Title')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ## Problems

# %%
df.head(5)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
df.job_posted_date.value_counts()
# Out:
# job_posted_date
# 2023-12-08 07:24:37    10
# 2023-01-08 00:19:57    10
# 2023-09-17 00:28:49    10
# 2023-09-07 00:07:24    10
# 2023-07-22 07:25:54    10
#                        ..
# 2023-05-17 17:27:41     1
# 2023-05-28 17:51:07     1
# 2023-09-05 17:10:27     1
# 2023-09-02 17:02:18     1
# 2023-03-12 06:32:36     1
# Name: count, Length: 607192, dtype: int64

# %%
df.pivot_table(index='job_country',columns='job_title_short', values='job_posted_date', aggfunc='count')
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# Afghanistan                   4.0             NaN           9.0
# Albania                      11.0             1.0          36.0
# Algeria                      21.0             5.0          22.0
# Angola                        1.0             NaN           2.0
# Argentina                   453.0           322.0        1273.0
# ...                           ...             ...           ...
# Venezuela                     2.0             2.0          16.0
# Vietnam                      91.0            70.0         334.0
# Yemen                         3.0             NaN           4.0
# Zambia                       30.0             4.0          40.0
# Zimbabwe                      6.0             3.0          34.0
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# Afghanistan                NaN             1.0                        NaN
# ...

# %%
job_postings_count = df.pivot_table(index='job_country',columns='job_title_short', values='job_posted_date', aggfunc='count')
job_postings_count
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# Afghanistan                   4.0             NaN           9.0
# Albania                      11.0             1.0          36.0
# Algeria                      21.0             5.0          22.0
# Angola                        1.0             NaN           2.0
# Argentina                   453.0           322.0        1273.0
# ...                           ...             ...           ...
# Venezuela                     2.0             2.0          16.0
# Vietnam                      91.0            70.0         334.0
# Yemen                         3.0             NaN           4.0
# Zambia                       30.0             4.0          40.0
# Zimbabwe                      6.0             3.0          34.0
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# Afghanistan                NaN             1.0                        NaN
# ...

# %%
job_postings_count = job_postings_count.loc[top_countries]
job_postings_count
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# United States              7382.0           423.0       67816.0
# India                      1887.0           351.0        6121.0
# United Kingdom              827.0           193.0       10482.0
# France                      738.0           338.0       13803.0
# Germany                     817.0           189.0        7131.0
# Spain                      1505.0           567.0        5177.0
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# United States          35080.0         58830.0                      921.0
# India                  19062.0         13279.0                      671.0
# United Kingdom         11807.0          9148.0                      317.0
# France                 10936.0          9497.0                      388.0
# Germany                 6675.0          6745.0                      402.0
# ...

# %%
job_postings_count = job_postings_count[job_titles]
job_postings_count
# Out:
# job_title_short  Data Analyst  Data Engineer  Data Scientist
# job_country
# United States         67816.0        35080.0         58830.0
# India                  6121.0        19062.0         13279.0
# United Kingdom        10482.0        11807.0          9148.0
# France                13803.0        10936.0          9497.0
# Germany                7131.0         6675.0          6745.0
# Spain                  5177.0         6740.0          5598.0

# %%
job_postings_count.plot(kind='bar')
# Out:
# <Axes: xlabel='job_country'>
